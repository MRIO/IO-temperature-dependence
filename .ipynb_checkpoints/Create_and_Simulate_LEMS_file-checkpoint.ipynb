# %%
import sys
from pyneuroml import pynml
from pyneuroml.lems.LEMSSimulation import LEMSSimulation
import neuroml as nml
from pyneuroml.pynml import print_comment_v

# %%
#Create and simulate file
def generate_Vm_vs_time_plot(nml2_file, 
                                        cell_id, 
                                        inj_amp_nA = 80,
                                        delay_ms = 20,
                                        inj_dur_ms = 60,
                                        sim_dur_ms = 100, 
                                        dt = 0.05,
                                        plot_voltage_traces=False,
                                        show_plot_already=True, 
                                        include_included=True):
                                            
    ref = "CandSmyfile"
    print_comment_v("Generating Vm(mV) vs Time(ms) plot for cell %s in %s (Inj %snA / %sms dur after %sms delay)"%
        (cell_id, nml2_file, inj_amp_nA, inj_dur_ms, delay_ms))
    
    sim_id = 'Vm_%s'%ref
    duration = sim_dur_ms
    ls = LEMSSimulation(sim_id, sim_dur_ms, dt)
    
    ls.include_neuroml2_file(nml2_file, include_included=include_included)
    ls.assign_simulation_target('network')
    nml_doc = nml.NeuroMLDocument(id=cell_id)
    
    nml_doc.includes.append(nml.IncludeType(href=nml2_file))
    
    net = nml.Network(id="network")
    nml_doc.networks.append(net)
    
    input_id = ("input_%s"%str(inj_amp_nA).replace('.','_'))
    pg = nml.PulseGenerator(id=input_id,
                                    delay="%sms"%delay_ms,
                                    duration='%sms'%inj_dur_ms,
                                    amplitude='%spA'%inj_amp_nA)
    nml_doc.pulse_generators.append(pg)
    
    
    pop_id = 'pop24'
    pop = nml.Population(id=pop_id, component='iclamp0', size=1, type="populationList")
    
    inst = nml.Instance(id=0)
    pop.instances.append(inst)
    inst.location = nml.Location(x=0, y=800, z=0)
    net.populations.append(pop)
    
    # Add these to cells
    input_list = nml.InputList(id='il_%s'%input_id,
                                 component=pg.id,
                                 populations=pop_id)
    input = nml.Input(id='0',  target='../pop24/0/C51A',
                              destination="synapses")  
    
    input_list.input.append(input)
    net.input_lists.append(input_list)
    
    sim_file_name = '%s.sim.nml'%sim_id
    pynml.write_neuroml2_file(nml_doc, sim_file_name)
    ls.include_neuroml2_file(sim_file_name)


    disp0 = 'Voltage_display'
    ls.create_display(disp0,"Voltages", "-90", "50")
    ls.add_line_to_display(disp0, "V", "pop24/0/C51A/v", scale='1mV')
    
    of0 = 'Volts_file'
    ls.create_output_file(of0, "%s.v.dat"%sim_id)
    ls.add_column_to_output_file(of0, "V", "pop24/0/C51A/v")
    
    lems_file_name = ls.save_to_file()
    
    results = pynml.run_lems_with_jneuroml(lems_file_name, 
                                            nogui=True, 
                                            load_saved_data=True, 
                                            plot=plot_voltage_traces,
                                            show_plot_already=False)
                                                
 
    if show_plot_already:
        from matplotlib import pyplot as plt
        plt.show()
        
    return of0

# %%
generate_Vm_vs_time_plot('nml_c51_onsite.net.nml', 'C51A')
# Out:
# pyNeuroML >>> Generating Vm(mV) vs Time(ms) plot for cell C51A in nml_c51_onsite.net.nml (Inj 80nA / 60ms dur after 20ms delay)
# pyNeuroML >>> Written LEMS Simulation Vm_CandSmyfile to file: LEMS_Vm_CandSmyfile.xml
# pyNeuroML >>> *** Problem running command:
# pyNeuroML >>>        Command 'java -Xmx400M  -jar  "C:\Users\naomi\AppData\Local\Miniconda3\envs\neuroMLenv27\lib\site-packages\pyneuroml\lib\jNeuroML-0.10.0-jar-with-dependencies.jar"  "LEMS_Vm_CandSmyfile.xml"  -nogui' returned non-zero exit status 1
# pyNeuroML >>>  jNeuroML >>   jNeuroML v0.10.0
# pyNeuroML >>>  jNeuroML >>  Loading: C:\Users\naomi\OneDrive\Documenten\Neurocomputing\GitHub\IO-temperature-dependence\Cells\LEMS_Vm_CandSmyfile.xml with jLEMS, NO GUI mode...
# pyNeuroML >>>  jNeuroML >>  INFO Oct 15,2020 15:48  (INFO) Loading LEMS file from: C:\Users\naomi\OneDrive\Documenten\Neurocomputing\GitHub\IO-temperature-dependence\Cells\LEMS_Vm_CandSmyfile.xml
# pyNeuroML >>>  jNeuroML >>  INFO Oct 15,2020 15:48  (INFO) Reading from: C:\Users\naomi\OneDrive\Documenten\Neurocomputing\GitHub\IO-temperature-dependence\Cells\LEMS_Vm_CandSmyfile.xml
# pyNeuroML >>>  jNeuroML >>  INFO Oct 15,2020 15:48  (LOG)   at org.lemsml.jlems.core.logging.E.multiError(E.java:251)
# pyNeuroML >>>  jNeuroML >>  INFO Oct 15,2020 15:48  (LOG)   at org.lemsml.jlems.core.logging.E.error(E.java:217)
# pyNeuroML >>>  jNeuroML >>  INFO Oct 15,2020 15:48  (LOG)   at org.lemsml.jlems.core.sim.AbstractInclusionReader.trimOuterElement(AbstractInclusionReader.java:113)
# pyNeuroML >>>  jNeuroML >>  INFO Oct 15,2020 15:48  (LOG)   at org.lemsml.jlems.core.sim.AbstractInclusionReader.getIncludeContent(AbstractInclusionReader.java:43)
# pyNeuroML >>>  jNeuroML >>  INFO Oct 15,2020 15:48  (LOG)   at org.neuroml.export.utils.NeuroMLInclusionReader.insertIncludes(NeuroMLInclusionReader.java:93)
# pyNeuroML >>>  jNeuroML >>  INFO Oct 15,2020 15:48  (LOG)   at org.lemsml.jlems.core.sim.AbstractInclusionReader.getIncludeContent(AbstractInclusionReader.java:42)
# pyNeuroML >>>  jNeuroML >>  INFO Oct 15,2020 15:48  (LOG)   at org.neuroml.export.utils.NeuroMLInclusionReader.insertIncludes(NeuroMLInclusionReader.java:93)
# pyNeuroML >>>  jNeuroML >>  INFO Oct 15,2020 15:48  (LOG)   at org.lemsml.jlems.core.sim.AbstractInclusionReader.getIncludeContent(AbstractInclusionReader.java:42)
# pyNeuroML >>>  jNeuroML >>  INFO Oct 15,2020 15:48  (LOG)   at org.lemsml.jlems.core.sim.AbstractInclusionReader.insertIncludes(AbstractInclusionReader.java:71)
# pyNeuroML >>>  jNeuroML >>  INFO Oct 15,2020 15:48  (LOG)   at org.neuroml.export.utils.NeuroMLInclusionReader.insertIncludes(NeuroMLInclusionReader.java:102)
# pyNeuroML >>>  jNeuroML >>
# pyNeuroML >>> Error: execute_command_in_dir returned with output: None
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: -1

# %%
#Create and simulate file (EXAMPLE)
import sys

from pyneuroml import pynml
from pyneuroml.lems.LEMSSimulation import LEMSSimulation
import neuroml as nml

from pyneuroml.pynml import print_comment_v

def generate_Vm_vs_time_plot2(nml2_file, 
                                        cell_id, 
                                        inj_amp_nA = 80,
                                        delay_ms = 20,
                                        inj_dur_ms = 60,
                                        sim_dur_ms = 100, 
                                        dt = 0.05,
                                        plot_voltage_traces=True,
                                        show_plot_already=True, 
                                        simulator="jNeuroML",
                                        include_included=True):
                                            
    ref = "CandSexample"
    print_comment_v("Generating Vm(mV) vs Time(ms) plot for cell %s in %s using %s (Inj %snA / %sms dur after %sms delay)"%
        (cell_id, nml2_file, simulator, inj_amp_nA, inj_dur_ms, delay_ms))
    
    sim_id = 'Vm_%s'%ref
    duration = sim_dur_ms
    ls = LEMSSimulation(sim_id, sim_dur_ms, dt)
    
    ls.include_neuroml2_file(nml2_file, include_included=include_included)
    ls.assign_simulation_target('network')
    nml_doc = nml.NeuroMLDocument(id=cell_id)
    
    nml_doc.includes.append(nml.IncludeType(href=nml2_file))
    
    net = nml.Network(id="network")
    nml_doc.networks.append(net)
    
    input_id = ("input_%s"%str(inj_amp_nA).replace('.','_'))
    pg = nml.PulseGenerator(id=input_id,
                                    delay="%sms"%delay_ms,
                                    duration='%sms'%inj_dur_ms,
                                    amplitude='%spA'%inj_amp_nA)
    nml_doc.pulse_generators.append(pg)
    
    
    pop_id = 'hhpop'
    pop = nml.Population(id=pop_id, component='hhcell', size=1, type="populationList")
    
    inst = nml.Instance(id=0)
    pop.instances.append(inst)
    inst.location = nml.Location(x=0, y=0, z=0)
    net.populations.append(pop)
    
    # Add these to cells
    input_list = nml.InputList(id='il_%s'%input_id,
                                 component=pg.id,
                                 populations=pop_id)
    input = nml.Input(id='0',  target='../hhpop/0/hhcell',
                              destination="synapses")  
    
    input_list.input.append(input)
    net.input_lists.append(input_list)
    
    sim_file_name = '%s.sim.nml'%sim_id
    pynml.write_neuroml2_file(nml_doc, sim_file_name)
    ls.include_neuroml2_file(sim_file_name)


    disp0 = 'Voltage_display'
    ls.create_display(disp0,"Voltages", "-90", "50")
    ls.add_line_to_display(disp0, "V", "hhpop/0/hhcell/v", scale='1mV')
    
    of0 = 'Volts_file'
    ls.create_output_file(of0, "%s.v.dat"%sim_id)
    ls.add_column_to_output_file(of0, "V", "hhpop/0/hhcell/v")
    
    lems_file_name = ls.save_to_file()
    
    if simulator == "jNeuroML":
        results = pynml.run_lems_with_jneuroml(lems_file_name, 
                                                nogui=True, 
                                                load_saved_data=True, 
                                                plot=plot_voltage_traces,
                                                show_plot_already=False)
    elif simulator == "jNeuroML_NEURON":
        results = pynml.run_lems_with_jneuroml_neuron(lems_file_name, 
                                                nogui=True, 
                                                load_saved_data=True, 
                                                plot=plot_voltage_traces,
                                                show_plot_already=False)
                                                
 
    if show_plot_already:
        from matplotlib import pyplot as plt
        plt.show()
        
        
    return of0

# %%
generate_Vm_vs_time_plot2('NML2_SingleCompHHCell.nml', 'hhcell')
# Out:
# pyNeuroML >>> Generating Vm(mV) vs Time(ms) plot for cell hhcell in NML2_SingleCompHHCell.nml using jNeuroML (Inj 80nA / 60ms dur after 20ms delay)
# pyNeuroML >>> Written LEMS Simulation Vm_CandSexample to file: LEMS_Vm_CandSexample.xml
# pyNeuroML >>> Reloading data specified in LEMS file: LEMS_Vm_CandSexample.xml (C:\Users\naomi\OneDrive\Documenten\Neurocomputing\GitHub\IO-temperature-dependence\Cells\LEMS_Vm_CandSexample.xml), base_dir: ., cwd: C:\Users\naomi\OneDrive\Documenten\Neurocomputing\GitHub\IO-temperature-dependence\Cells
# pyNeuroML >>> Reloading: Data loaded from .\Vm_CandSexample.v.dat (jNeuroML)
# 'Volts_file'
