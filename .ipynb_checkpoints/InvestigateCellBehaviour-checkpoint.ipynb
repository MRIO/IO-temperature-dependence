# %%
import sys
import csv
import os
import pandas as pd
import numpy as np
import decimal
from pyneuroml import pynml
from pyneuroml.pynml import print_comment_v
from pyneuroml.lems import LEMSSimulation
import neuroml as nml
import neuroml.writers as writers
from neuroml.utils import validate_neuroml2
import random
random.seed(12345)
# %matplotlib inline

#from platform import python_version
#print(python_version())

os.getcwd()
# Out:
# '/home/jovyan/work/NeuroML_Examples/Naomi/temperatureDependence'

# %% [markdown]
# # Generating NML files and running simulations at specific temperatures
# ~ *Investigate the difference between voltage traces recorded at the soma and at a distal dendrite*
#
# The code in this notebook:
# - Creates a network NML file consisting of
#     - An isolated cell at the center of the network. This cell is loaded into the file from an existing cell NML file *cellName*_scaled_exp_resample_5.cell.nml, where *cellName* has to be defined by the user. Available files can be found in the folder \NMLfiles\Cells.
#     - A pulse generator exciting the soma of the cell.
# - Creates a LEMS file containing all information about running a simulation of the network NML file. Most importantly, the measured quantity is the voltage over the membrane in two compartments: the soma and a distal dendrite.
# - Runs the LEMS file that is generated with Neuron.
#
# All of the above is done in a for-loop, looping over a user-defined list of temperatures. Simulation results are stored in a dictionary named `output_dict`.

# %%
output_dict = {}
path = os.getcwd()

#Create list of temperatures to perform the experiments at
start = 20 
stop = 37
step = 17
temp_range = np.arange(start, stop + step, step)

#Choose a cell to investigate
cellName = "C11A"
segNrDistalDendr = 310 #from the NML file, derive which segment corresponds to a distal dendrite and write its segment id here

for i in temp_range:
    i = round(i,2)
    nml_doc = nml.NeuroMLDocument(id="net")

    #Include cell file
    incl = nml.IncludeType(href=cellName+"_scaled_exp_resample_5.cell.nml")
    nml_doc.includes.append(incl)

    #Create network
    net = nml.Network(id="net", type="networkWithTemperature", temperature=str(i)+"degC")
    nml_doc.networks.append(net)

    #Create population
    pop = nml.Population(id="pop", component=cellName, type="populationList", size="1")
    net.populations.append(pop)

    loc = nml.Location(x="0", y="0", z="0")

    inst = nml.Instance(id="0", location=loc)
    pop.instances.append(inst)
  
    #Create pulse generator
    t_delay = 200
    t_duration = 50
    
    pg = nml.PulseGenerator(id="iclamp0", delay=str(t_delay)+"ms", duration=str(t_duration)+"ms", amplitude="-1nA")
    nml_doc.pulse_generators.append(pg)

    #Add pg to cell
    il = nml.InputList(id="clamps", component=pg.id, populations="pop")
    ip = nml.Input(id="0", target="../pop/0/"+str(cellName), segmentId="0", destination="synapses")
    il.input.append(ip)
    net.input_lists.append(il)

    #Write NML file
    nml_file = "nml_"+cellName+".net.nml"
    writers.NeuroMLWriter.write(nml_doc, nml_file)

    #Validate NML file
    validate_neuroml2(nml_file)
    
    #Define simulation characteristics
    ref = "Test"
    sim_id = "Vm_%s"%ref
    sim_dur_ms = 1000
    dt = 0.05
    
    #Determine output variables
    segment = [0, segNrDistalDendr] #segments to record the potential at; has to be tuned for the cell you are considering
    quantity = []
    for s in segment:
        quantity.append("pop/0/"+cellName+"/"+str(s)+"/v")
    target = 'net'

    #Create LEMS file
    ls = LEMSSimulation(sim_id, sim_dur_ms, dt, target = target)
    ls.include_neuroml2_file("nml_"+cellName+".net.nml")

    disp0 = 'display0'
    ls.create_display(disp0, "Spiking pattern", "-90", "50")
    for j in range(len(quantity)):
        ls.add_line_to_display(disp0, segment[j], quantity[j])

    of0 = 'Volts_file'
    ls.create_output_file(of0, "%s.v.dat"%sim_id)
    for j in range(len(quantity)): 
        ls.add_column_to_output_file(of0, segment[j], quantity[j])
        print(segment[j])
        print(quantity[j])
        
    #Write LEMS file
    fn = "LEMS_%s.xml"%sim_id
    ls.save_to_file(file_name=fn)

    lems_file = path+'/LEMS_Vm_Test.xml'

    out_dir,rel_filename = os.path.split(lems_file)
    print(out_dir)
    print(rel_filename)

    #Run LEMS file with Neuron
    results_dict = pynml.run_lems_with_jneuroml_neuron(
        rel_filename, verbose=False, nogui=True, load_saved_data=True, exec_in_dir=out_dir,
        max_memory='400M')
    
    #Store the results in output_dict
    for q in quantity:
        results_dict[str(q)+"."+str(i)+'degC'] = results_dict.pop(q) 
    output_dict.update(results_dict)
    print(output_dict.keys())
# Out:
# Validating nml_C11A.net.nml against /opt/conda/lib/python3.7/site-packages/neuroml/nml/NeuroML_v2.1.xsd
# It's valid!
# 0
# pop/0/C11A/0/v
# 310
# pop/0/C11A/310/v
# pyNeuroML >>> Written LEMS Simulation Vm_Test to file: LEMS_Vm_Test.xml
# /home/jovyan/work/NeuroML_Examples/Naomi/temperatureDependence
# LEMS_Vm_Test.xml
# pyNeuroML >>> Reloading data specified in LEMS file: LEMS_Vm_Test.xml (/home/jovyan/work/NeuroML_Examples/Naomi/temperatureDependence/LEMS_Vm_Test.xml), base_dir: /home/jovyan/work/NeuroML_Examples/Naomi/temperatureDependence, cwd: /home/jovyan/work/NeuroML_Examples/Naomi/temperatureDependence
# dict_keys(['t', 'pop/0/C11A/0/v.20degC', 'pop/0/C11A/310/v.20degC'])
# Validating nml_C11A.net.nml against /opt/conda/lib/python3.7/site-packages/neuroml/nml/NeuroML_v2.1.xsd
# It's valid!
# 0
# pop/0/C11A/0/v
# 310
# pop/0/C11A/310/v
# pyNeuroML >>> Written LEMS Simulation Vm_Test to file: LEMS_Vm_Test.xml
# /home/jovyan/work/NeuroML_Examples/Naomi/temperatureDependence
# ...

# %% [markdown]
# ## Plotting
# The code below plots the trace recorded at the soma as well as the one recorded at the distal dendrite at one chosen temperature. Also, a plot is made of the difference between the two traces.
#
# We see that the two traces are almost overlapping; the difference between the two is extremely small, indicating almost no attenuation of the oscillation along the dendrites. Increasing the resistivity value of 0.1 ohm cm to 1 ohm cm (which is still biologically plausible) still gives only very little attenuation. A possible explanantion is that the gapjunctions, which are not modelled, are crucial to reproduce the attenuation.

# %%
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

#Choose a temperature
temp = 37

plt.rcParams['figure.figsize'] = [10, 5]
plt.rcParams['axes.titlesize'] = 16

plt.xlabel('Time (s)')
plt.ylabel('Membrane potential (V)')
plt.title('Membrane potential at different locations')
plt.grid(True)

for key in output_dict:
    if key == 't':
        continue
    #Here comes the part sensible to errors:
    if key == "pop/0/"+cellName+"/0/v."+str(temp)+"degC" or key == "pop/0/"+cellName+"/"+str(segNrDistalDendr)+"/v."+str(temp)+"degC":
        plt.plot(output_dict['t'],output_dict[key], label=""+key)
    
plt.legend(["Soma", "Dendrite"])
plt.show()

#Plot the difference between the two traces
diff = []
vol0 = output_dict["pop/0/"+cellName+"/0/v."+str(temp)+"degC"]
volDD = output_dict["pop/0/"+cellName+"/"+str(segNrDistalDendr)+"/v."+str(temp)+"degC"]
for i in range(len(output_dict["pop/0/"+cellName+"/0/v."+str(temp)+"degC"])):
    diff.append(vol0[i]-volDD[i])

plt.figure()
plt.xlabel('Time (s)')
plt.ylabel('Membrane potential (V)')
plt.title('Difference in membrane potential between soma and dendrite')
plt.grid(True)
plt.plot(output_dict['t'],diff)
plt.show()
